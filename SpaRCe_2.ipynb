# %%
pip install reservoirpy
# Out:
# Requirement already satisfied: reservoirpy in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Requirement already satisfied: dill>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from reservoirpy) (0.3.9)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from reservoirpy) (1.4.2)
# Requirement already satisfied: numpy>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from reservoirpy) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from reservoirpy) (1.13.1)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.10/dist-packages (from reservoirpy) (4.66.6)

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import reservoirpy as rpy
from reservoirpy.nodes import Reservoir
import numpy as np
from scipy.sparse import random as sparse_random

# %%
# hyperparameters
reservoir_units = 500
spectral_radius = 0.9
input_scaling = 0.5
connectivity = 0.1

# %%
def preprocess_mnist(batch_size=64):
    transform = transforms.ToTensor()
    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
def initialize_reservoir(input_dim=28, reservoir_size=1000, spectral_radius=0.95, sparsity=0.1, gamma=1.0):
    # Generate a sparse random matrix
    W = sparse_random(reservoir_size, reservoir_size, density=sparsity, format="csr", data_rvs=np.random.randn).A

    # Scale the weights to set the spectral radius
    eigenvalues = np.linalg.eigvals(W)
    W *= spectral_radius / np.max(np.abs(eigenvalues))

    # Initialize the reservoir with the custom weights
    reservoir = Reservoir(
        reservoir_size,
        input_dim=input_dim,
        activation="tanh"
    )
    reservoir.W = W  # Set custom internal weights
    reservoir.gamma = gamma  # Set scaling factor for inputs

    return reservoir

# %%
# Compute n-th percentiles from V_tilde
def compute_percentiles(V_tilde_train, n=50):
    return np.percentile(np.abs(V_tilde_train), n, axis=0)

# %%
# Apply threshold to reservoir activities V_tilde (to get variable x)
def apply_threshold(V_tilde, percentiles, theta_tilde):
    abs_V_tilde = np.abs(V_tilde)
    thresholds = percentiles + theta_tilde
    x = np.sign(V_tilde) * np.maximum(abs_V_tilde - thresholds, 0)
    return x

# %%
# Train output layer - linear
class OutputLayer(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.fc = torch.nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return self.fc(x)

# %%
# Train model SpaRCe ESN
def train_SpaRCe(train_loader, reservoir, ridge_regressor, epochs=10):
    from sklearn.linear_model import Ridge
    import numpy as np
    import torch

    # Initialize data structures for collecting features and labels
    all_features = []
    all_labels = []

    print(f"Starting training for {epochs} epochs...\n")
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")

        for batch_idx, (images, labels) in enumerate(train_loader):
            # Present images column by column
            batch_features = []
            for image in images:  # Each image
                sequence = image.view(28, 28).T  # Present column by column
                reservoir_output = reservoir.run(sequence.numpy())
                # Apply the SpaRCe transformation here (if applicable)
                tilde_v = reservoir_output.flatten()
                batch_features.append(tilde_v)

            # Stack features and store labels
            all_features.append(np.array(batch_features))
            all_labels.extend(labels.numpy())

            if batch_idx % 10 == 0:  # Print every 10 batches
                print(f"  Processed batch {batch_idx + 1}/{len(train_loader)}")

    # Concatenate all features and labels
    X_train = np.concatenate(all_features, axis=0)
    y_train = np.array(all_labels)

    print("\nTraining Ridge Regressor...")
    ridge_regressor.fit(X_train, y_train)
    print("Training completed!")
    return ridge_regressor

# %%
# Evaluate the model
def evaluate(test_loader, reservoir, output_layer, percentiles, theta_tilde):
    correct = 0
    total = 0

    for images, targets in test_loader:
        images = images.squeeze(1)
        batch_states = []

        for t in range(28):
            column = images[:, :, t].numpy()
            state = reservoir.run(column)
            batch_states.append(state)

        reservoir_states = np.hstack(batch_states)
        sparse_states = apply_threshold(reservoir_states, percentiles, theta_tilde)

        sparse_states_tensor = torch.tensor(sparse_states, dtype=torch.float32)
        outputs = output_layer(sparse_states_tensor)
        _, predicted = torch.max(outputs.data, 1)

        total += targets.size(0)
        correct += (predicted == targets).sum().item()

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")

# %%
# Testing the model
from sklearn.linear_model import Ridge

train_loader, test_loader = preprocess_mnist()
reservoir = initialize_reservoir()
ridge_regressor = Ridge(alpha=1.0)  # Regularization parameter can be tuned
output_layer = train_SpaRCe(train_loader, reservoir, ridge_regressor)
evaluate(test_loader, reservoir, output_layer)
# Out:
# Starting training for 10 epochs...
#
# Epoch 1/10
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1298.55it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 555.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1726.94it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 618.83it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 551.01it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1409.26it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1593.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 355.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 917.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1407.62it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1610.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1392.51it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1583.20it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 530.87it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 825.70it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 773.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 611.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1600.86it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1670.63it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 853.56it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 796.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 635.74it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 946.06it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1062.19it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1182.97it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1350.71it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 928.10it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 541.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 681.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 834.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 700.90it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 856.44it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 995.46it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 962.55it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1268.69it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1478.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1502.35it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1762.13it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1293.27it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1332.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1506.19it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1265.30it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1454.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 436.98it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 645.01it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1258.31it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1573.43it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1624.89it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1834.86it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1817.94it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1691.67it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1412.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1258.75it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1718.88it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 869.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1635.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1623.65it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1717.22it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1235.31it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1086.32it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1762.18it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1777.54it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1465.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1743.58it/s]
#   Processed batch 1/938
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 688.74it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1525.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1375.55it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1561.23it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1425.72it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1376.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1461.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 925.25it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1359.72it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1343.01it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 877.00it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1026.05it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 898.33it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 727.34it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1465.48it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 794.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 528.25it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 912.39it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 504.19it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 458.13it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 928.94it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 720.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1058.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1079.45it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 468.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 839.80it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 700.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1230.83it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 745.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 618.68it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 751.28it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 621.76it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 502.32it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 990.31it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1694.23it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 963.09it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 701.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1371.87it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1507.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1117.93it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 514.34it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 569.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 666.93it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 321.54it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 421.39it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1068.73it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 992.68it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1147.52it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1269.63it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1211.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1539.48it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1448.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1495.33it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1306.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1355.92it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1038.00it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 892.69it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 491.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 765.10it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1133.76it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1033.63it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1001.30it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1222.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1161.88it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1088.91it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1028.62it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1318.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1348.53it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 965.98it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 930.43it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1341.75it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1633.09it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1770.95it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1515.30it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1353.47it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1381.65it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1488.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 964.48it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1500.80it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1515.24it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1423.11it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1595.51it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1571.19it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 926.63it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1718.52it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1598.63it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1680.72it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1564.89it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 814.71it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 848.96it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 442.29it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1007.31it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 790.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1600.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1258.04it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1649.75it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 964.25it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1398.95it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1129.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1325.20it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1344.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1285.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 521.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1598.29it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1503.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 758.57it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 748.28it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1098.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1521.45it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1580.35it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1346.89it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 781.85it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1641.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1541.64it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1463.38it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 572.50it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 604.03it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1473.51it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 611.05it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 253.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 280.05it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 529.50it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 400.10it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 453.22it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 661.24it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 606.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 752.97it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 690.44it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 399.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 533.39it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 836.48it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 536.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1503.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 739.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 775.99it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 612.11it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 626.55it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 721.24it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 868.39it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 680.33it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 708.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1065.33it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 699.52it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 285.67it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 663.02it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 549.83it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 423.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 250.87it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 385.20it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 403.64it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 720.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 507.36it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1286.27it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1197.49it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 714.85it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 401.98it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 389.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 713.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 443.90it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 715.22it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1173.81it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 463.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 721.29it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 749.02it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 493.76it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 540.02it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 604.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 687.50it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 685.87it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 901.34it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 589.05it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 513.80it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 217.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 910.17it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 973.25it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 331.75it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 270.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 541.14it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 750.14it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 713.09it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 821.17it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 846.44it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 691.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 667.65it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 328.78it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 445.91it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 567.65it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 542.28it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 511.83it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 426.96it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 424.20it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 372.04it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 403.28it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 290.34it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1120.86it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1198.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1242.49it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 361.53it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 292.36it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 331.97it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 624.98it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 524.46it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 819.03it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1152.87it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 848.43it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 343.93it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 334.60it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 749.39it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1540.73it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 633.95it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 237.06it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 562.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 536.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 518.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 583.09it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 540.62it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 617.08it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 766.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 971.00it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1737.77it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1773.62it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1611.95it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1113.50it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 983.91it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 916.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1685.84it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1587.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1756.51it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1715.14it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1136.03it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1314.33it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1433.06it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1394.45it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1412.58it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 591.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 516.88it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1343.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 984.41it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 493.06it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 516.49it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 898.95it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1124.75it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 491.13it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1669.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1638.54it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 399.21it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 525.45it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 659.42it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 690.12it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1647.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1087.26it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1043.10it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1285.15it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 572.16it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1132.25it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1222.54it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 925.53it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1622.40it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1222.52it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 619.67it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 750.82it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 989.26it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1310.71it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 552.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 451.93it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 146.59it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 349.86it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 529.18it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1019.86it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1204.47it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 948.26it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1506.92it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1291.43it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1532.57it/s]
# Running Reservoir-0: 100%|██████████| 28/28 [00:00<00:00, 1214.60it/s]
# Running Reservoir-0:   0%|          | 0/28 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1d2d64914c9a> in <cell line: 7>()
#       5 reservoir = initialize_reservoir()
#       6 ridge_regressor = Ridge(alpha=1.0)  # Regularization parameter can be tuned
# ----> 7 output_layer = train_SpaRCe(train_loader, reservoir, ridge_regressor)
#       8 evaluate(test_loader, reservoir, output_layer)
#
# <ipython-input-10-b898037bb357> in train_SpaRCe(train_loader, reservoir, ridge_regressor, epochs)
#      18             for image in images:  # Each image
#      19                 sequence = image.view(28, 28).T  # Present column by column
# ---> 20                 reservoir_output = reservoir.run(sequence.numpy())
#      21                 # Apply the SpaRCe transformation here (if applicable)
#      22                 tilde_v = reservoir_output.flatten()
#
# /usr/local/lib/python3.10/dist-packages/reservoirpy/node.py in run(self, X, from_state, stateful, reset)
#     940         with self.with_state(from_state, stateful=stateful, reset=reset):
#     941             states = np.zeros((seq_len, self.output_dim))
# --> 942             for i in progress(range(seq_len), f"Running {self.name}: "):
#     943                 if isinstance(X_, (list, tuple)):
#     944                     x = [np.atleast_2d(Xi[i]) for Xi in X_]
#
# /usr/local/lib/python3.10/dist-packages/reservoirpy/utils/__init__.py in progress(it, *args, **kwargs)
#      20 def progress(it, *args, **kwargs):
#      21     if VERBOSITY > 0:
# ---> 22         return tqdm(it, *args, **kwargs)
#      23     else:
#      24         return it
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, write_bytes, lock_args, nrows, colour, delay, gui, **kwargs)
#    1096             self.sp = self.status_printer(self.fp)
#    1097             if delay <= 0:
# -> 1098                 self.refresh(lock_args=self.lock_args)
#    1099
#    1100         # Init the time counter
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in refresh(self, nolock, lock_args)
#    1345             else:
#    1346                 self._lock.acquire()
# -> 1347         self.display()
#    1348         if not nolock:
#    1349             self._lock.release()
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in display(self, msg, pos)
#    1493         if pos:
#    1494             self.moveto(pos)
# -> 1495         self.sp(self.__str__() if msg is None else msg)
#    1496         if pos:
#    1497             self.moveto(-pos)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in print_status(s)
#     457         def print_status(s):
#     458             len_s = disp_len(s)
# --> 459             fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460             last_len[0] = len_s
#     461
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in fp_write(s)
#     450
#     451         def fp_write(s):
# --> 452             fp.write(str(s))
#     453             fp_flush()
#     454
#
# /usr/local/lib/python3.10/dist-packages/tqdm/utils.py in inner(*args, **kwargs)
#     194         def inner(*args, **kwargs):
#     195             try:
# --> 196                 return func(*args, **kwargs)
#     197             except OSError as e:
#     198                 if e.errno != 5:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     618                 )
#     619             data.group = group
# --> 620         return super().send(data, flags=flags, copy=copy, track=track)
#     621
#     622     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
